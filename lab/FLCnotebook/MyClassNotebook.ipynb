# %% [markdown]
# # Title
#
# Put introductory text here.

# %%
# Add this cell if you want to import and/or graph data in your notebook. Otherwise, delete it.

# Run this cell, but please don't change it.

# These lines import the Numpy and Datascience modules.
import numpy as np
from datascience import *

# These lines do some fancy plotting magic.
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')
import warnings
warnings.simplefilter('ignore', FutureWarning)

import d8error

# %% [markdown]
# ## Subsection Title
#
# Insert more text here.

# %%
# This is how to display a YouTube video in a
# Jupyter notebook if you need this.  
# The argument to YouTubeVideo is the part
# of the URL (called a "query parameter") that identifies the
# video.  For example, the full URL for this video is:
#   https://www.youtube.com/watch?v=wE8NDuzt8eg
from IPython.display import YouTubeVideo
YouTubeVideo("wE8NDuzt8eg")

# %% [markdown]
# ### Subsubsection Title
#
# Insert more text here.
#
# If you want students to answer a question with a sentence, the input can be taken as follows with just a blank Markdown box. For instance,
#
# <!-- BEGIN QUESTION -->
#
# **Question 1.** The data were gathered by the following procedure, reported in the study. "Between January and June 1998, parents of children aged 2-16 years [...] that were seen as outpatients in a university pediatric ophthalmology clinic completed a questionnaire on the child's light exposure both at present and before the age of 2 years." Was this study observational, or was it a controlled experiment? Explain. **(5 Points)**

# %% [markdown]
# If instead, you want to have a multiple choice question, you can use this:
#
# **Multiple Choice Question 2.** Question goes here? Assign either 1, 2, 3, or 4 to the name `answer_q2` below. **(4 Points)**
#
# 1. Answer 1
# 2. Answer 2
# 3. Answer 3
# 4. Answer 4

# %%
answer_q2 = ...

# %% [markdown]
# # Subsection: Data and Images
#
# Remember, loading data works by executing codes like:
# `MyData = Table.read_table("data.csv")`
# within a code cell.
#
# Upload any csv file directly into your directory on this hub. To do this:
# 1. Click on the url at the top of this page, remove anything after `materials-sp22/lab/FLCnotebook`
# 2. Click on Upload in the upper corner of the directory as shown in the image below.![DirectoryUpload.png](attachment:DirectoryUpload.png)
# 3. Upoad any csv file you have.
#
# If you want to add images to your markdown cells, you simply can drag and drop images into the cell. That's what I did for the image above!
